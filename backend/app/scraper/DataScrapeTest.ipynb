# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# %%
options = Options()
options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36")
service = Service(ChromeDriverManager().install())

# %%
driver = webdriver.Chrome(service=service, options=options)
driver.get("https://www.realtor.com/realestateandhomes-search/13337")
print(driver.page_source)
# Out:
# <html lang="en"><head><script async="" src="https://bat.bing.com/p/insights/s/0.7.68"></script><script async="" src="https://bat.bing.com/p/insights/t/25046895"></script><script type="text/javascript" async="" src="https://bat.bing.com/bat.js"></script><script type="text/javascript" src="https://cdn.segment.com/next-integrations/integrations/vendor/commons.a61d7bea37d2de5d4b69.js.gz" async="" status="loaded"></script><script type="text/javascript" src="https://cdn.segment.com/next-integrations/integrations/bing-ads/2.0.1/bing-ads.dynamic.js.gz" async="" status="loaded"></script><script async="" crossorigin="anonymous" src="https://edge.fullstory.com/s/fs.js"></script><script type="text/javascript" async="" src="https://connect.facebook.net/en_US/fbevents.js"></script><script type="text/javascript" async="" src="https://bat.bing.com/bat.js"></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/js?id=G-MS5EHT6J6V&amp;l=dataLayerGTM&amp;cx=c&amp;gtm=45He52d0v9196239944za200"></script><script type="text/javascript" async="" src="https://dynamic.criteo.com/js/ld/s2s.js?p=114034&amp;c=880&amp;j=crto_callback_NewsAndInsights"></script><script type="text/javascript" async="" src="https://dynamic.criteo.com/js/ld/s2s.js?p=111011&amp;c=880&amp;j=crto_callback_Rental"></script><script type="text/javascript" async="" src="https://dynamic.criteo.com/js/ld/s2s.js?p=62680&amp;c=880&amp;j=crto_callback_ForSale"></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/js?id=AW-1049445407&amp;l=dataLayerGTM&amp;cx=c&amp;gtm=45He52d0v9196239944za200"></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/js?id=G-07XBH6XBNS&amp;l=dataLayerGTM&amp;cx=c&amp;gtm=45He52d0v9196239944za200"></script><script src="https://rules.quantcount.com/rules-p-StNwVtkUGv5N3.js" async=""></script><script async="" defer="" src="https://launchpad.privacymanager.io/latest/launchpad.bundle.js"></script><script src="//pixel.everesttech.net/rlsa/5154" async=""></script><script type="text/javascript" async="" src="https://cdn.segment.com/analytics.js/v1/AQDwyFATlYKIsir9uod3ma82uVwkfkGN/analytics.min.js"></script><script src="//bat.bing.com/bat.js" async=""></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-PZGTLTW6&amp;l=dataLayerGTM"></script><script src="https://connect.facebook.net/signals/config/754678604575607?v=2.9.183&amp;r=stable&amp;domain=www.realtor.com&amp;hme=bee25cb0600224fcc4f0d196cf8b317f393971b6cb1ab6b3c683da99b92af569&amp;ex_m=70%2C122%2C107%2C111%2C61%2C4%2C100%2C69%2C16%2C97%2C89%2C51%2C54%2C173%2C176%2C188%2C184%2C185%2C187%2C29%2C101%2C53%2C77%2C186%2C168%2C171%2C181%2C182%2C189%2C132%2C41%2C191%2C192%2C34%2C144%2C15%2C50%2C197%2C196%2C134%2C18%2C40%2C1%2C43%2C65%2C66%2C67%2C71%2C93%2C17%2C14%2C96%2C92%2C91%2C108%2C52%2C110%2C39%2C109%2C30%2C94%2C26%2C169%2C172%2C141%2C86%2C56%2C84%2C33%2C73%2C0%2C95%2C32%2C28%2C82%2C83%2C88%2C47%2C46%2C87%2C37%2C11%2C12%2C13%2C6%2C7%2C25%2C22%2C23%2C57%2C62%2C64%2C75%2C102%2C27%2C76%2C9%2C8%2C80%2C48%2C21%2C104%2C103%2C105%2C98%2C10%2C20%2C3%2C38%2C74%2C19%2C5%2C90%2C81%2C44%2C35%2C85%2C2%2C36%2C63%2C42%2C106%2C45%2C79%2C68%2C112%2C60%2C59%2C31%2C99%2C58%2C55%2C49%2C78%2C72%2C24%2C113" async=""></script><script async="" src="https://connect.facebook.net/en_US/fbevents.js"></script><script src="https://partner.googleadservices.com/gampad/cookie.js?domain=www.realtor.com&amp;client=partner-pub-6783813218254212&amp;product=SAS&amp;callback=__sasCookie&amp;cookie_types=v1%2Cv2"></script><script src="https://tagan.adlightning.com/realtor/bl-b62f438-4f7df2a7.js" type="text/javascript" defer=""></script><script src="https://tagan.adlightning.com/realtor/b-9d706ea-9169736e.js" type="text/javascript" defer=""></script><script type="text/javascript"></script><meta charset="utf-8"><script>window.kxdl = { jy: '' }; window.rdcdl = window.kxdl;  window.rdcdl.globalholdout = { isEnabled: window?. ...
# (()=>{var e,t,r={8122:(e,t,r)=>{"use strict";r.d(t,{a:()=>i});var n=r(944);function i(e,t){try{if(!e||"object"!=typeof e)return(0,n.R)(3);if(!t||"object"!=typeof t)return(0,n.R)(4);const r=Object.create(Object.getPrototypeOf(t),Object.getOwnPropertyDescriptors(t)),o=0===Object.keys(r).length?e:r;for(let a in o)if(void 0!==e[a])try{if(null===e[a]){r[a]=null;continue}Array.isArray(e[a])&&Array.isArray(t[a])?r[a]=Array.from(new Set([...e[a],...t[a]])):"object"==typeof e[a]&&"object"==typeof t[a]?r[a]=i(e[a],t[a]):r[a]=e[a]}catch(e){(0,n.R)(1,e)}return r}catch(e){(0,n.R)(2,e)}}},2555:(e,t,r)=>{"use strict";r.d(t,{Vp:()=>c,fn:()=>s,x1:()=>u});var n=r(384),i=r(8122);const o={beacon:n.NT.beacon,errorBeacon:n.NT.errorBeacon,licenseKey:void 0,applicationID:void 0,sa:void 0,queueTime:void 0,applicationTime:void 0,ttGuid:void 0,user:void 0,account:void 0,product:void 0,extra:void 0,jsAttributes:{},userAttributes:void 0,atts:void 0,transactionName:void 0,tNamePlain:void 0},a={};function s(e){try{const t=c(e);return!!t.licenseKey&&!!t.errorBeacon&&!!t.applicationID}catch(e){return!1}}function c(e){if(!e)throw new Error("All info objects require an agent identifier!");if(!a[e])throw new Error("Info for ".concat(e," was never set"));return a[e]}function u(e,t){if(!e)throw new Error("All info objects require an agent identifier!");a[e]=(0,i.a)(t,o);const r=(0,n.nY)(e);r&&(r.info=a[e])}},9417:(e,t,r)=>{"use strict";r.d(t,{D0:()=>p,gD:()=>m,xN:()=>g});var n=r(3333),i=r(993);const o=e=>{if(!e||"string"!=typeof e)return!1;try{document.createDocumentFragment().querySelector(e)}catch{return!1}return!0};var a=r(2614),s=r(944),c=r(384),u=r(8122);const d="[data-nr-mask]",l=()=>{const e={feature_flags:[],experimental:{marks:!1,measures:!1,resources:!1},mask_selector:"*",block_selector:"[data-nr-block]",mask_input_options:{color:!1,date:!1,"datetime-local":!1,email:!1,month:!1,number:!1,range:!1,search:!1,tel:!1,text:!1,time:!1,url:!1,week:!1,textarea:!1,select:!1,password:!0}};return{ajax:{deny_list:void 0,block_internal:!0,enabled:!0,autoStart:!0},distributed_tracing:{enabled:void 0,exclude_newrelic_header:void 0,cors_use_newrelic_header:void 0,cors_use_tracecontext_headers:void 0,allowed_origins:void 0},get feature_flags(){return e.feature_flags},set feature_flags(t){e.feature_flags=t},generic_events:{enabled:!0,autoStart:!0},harvest:{interval:30},jserrors:{enabled:!0,autoStart:!0},logging:{enabled:!0,autoStart:!0,level:i.p_.INFO},metrics:{enabled:!0,autoStart:!0},obfuscate:void 0,page_action:{enabled:!0},page_view_event:{enabled:!0,autoStart:!0},page_view_timing:{enabled:!0,autoStart:!0},performance:{get capture_marks(){return e.feature_flags.includes(n.$v.MARKS)||e.experimental.marks},set capture_marks(t){e.experimental.marks=t},get capture_measures(){return e.feature_flags.includes(n.$v.MEASURES)||e.experimental.measures},set capture_measures(t){e.experimental.measures=t},capture_detail:!0,resources:{get enabled(){return e.feature_flags.includes(n.$v.RESOURCES)||e.experimental.resources},set enabled(t){e.experimental.resources=t},asset_types:[],first_party_domains:[],ignore_newrelic:!0}},privacy:{cookies_enabled:!0},proxy:{assets:void 0,beacon:void 0},session:{expiresMs:a.wk,inactiveMs:a.BB},session_replay:{autoStart:!0,enabled:!1,preload:!1,sampling_rate:10,error_sampling_rate:100,collect_fonts:!1,inline_images:!1,fix_stylesheets:!0,mask_all_inputs:!0,get mask_text_selector(){return e.mask_selector},set mask_text_selector(t){o(t)?e.mask_selector="".concat(t,",").concat(d):""===t||null===t?e.mask_selector=d:(0,s.R)(5,t)},get block_class(){return"nr-block"},get ignore_class(){return"nr-ignore"},get mask_text_class(){return"nr-mask"},get block_selector(){return e.block_selector},set block_selector(t){o(t)?e.block_selector+=",".concat(t):""!==t&&(0,s.R)(6,t)},get mask_input_options(){return e.mask_input_options},set mask_input_options(t){t&&"object"==typeof t?e.mask_input_options={...t,password:!0}:(0,s.R)(7,t)}},session_trace:{enabled:!0,autoStart:! ...
#   window.ignoreNextComscorePixelForPage = window.location.origin + window.location.pathname;
#   var cookie, doc;
#   var shareData = navigator.doNotTrack === '1' || navigator.globalPrivacyControl === true || /ccpaoptout=true/.test(document.cookie) ? 0 : 1;
#   var tag = {
#     cs_fpid: ((cookie = document.cookie.split(';').filter(function (c) {
#       return c.trim().startsWith('__vst=');
#     })) === null || cookie === void 0 || (cookie = cookie.at(0)) === null || cookie === void 0 || (cookie = cookie.split('=')) === null || cookie === void 0 || (cookie = cookie.at(1)) === null || cookie === void 0 ? void 0 : cookie.trim()) || new URLSearchParams(new URL(window.location.href).search).get('iFrame_edwVisitorId') || null,
#     cs_ucfr: shareData,
#     cs_fpit: 'c',
#     cs_fpdm: '*null',
#     cs_fpdt: '*null',
#     c1: '2',
#     c2: '6036093'
#
#   };
#   window._comscore = window._comscore || [];
#   window._comscore.push(tag);
# </script><script src="https://sb.scorecardresearch.com/cs/6036093/beacon.js" async=""></script><script>var originalFunction = console.error;console.error = function() {  var args = Array.prototype.slice.call(arguments);  var error = new Error();  var stack = error.stack || "";  var firstPartyError = (stack.split(window.location.origin).length - 1) > 2;  if (window.newrelic && window.newrelic.noticeError) {    try {      if (false && !firstPartyError) {        return originalFunction.apply(console, args);      }      window.newrelic.noticeError(new Error(args[0]), { reason: (JSON.stringify(stack) || args[1] || "-"), firstPartyError: firstPartyError });    } catch (e) {      if (Array.isArray(args) && args.length) {        window.newrelic.noticeError(new Error(args[0], { reason: "Catch: " + (args[1] || "-"), firstPartyError: firstPartyError }));      }    }  }  return originalFunction.apply(console, args);}</script><script>
#     try {
#         const referrerCookieValue = document.cookie.split(';').find(c => c.trim().startsWith('KP_REF='));
#
#         const referrer = referrerCookieValue ?
#             atob(referrerCookieValue.substring(referrerCookieValue.indexOf('=') + 1, referrerCookieValue.length))
#             : undefined;
#
#         if (referrer !== undefined) {
#             Object.defineProperty(document, 'referrer', {
#                 value: referrer,
#                 writable: false
#             });
#         }
#
#         if (referrerCookieValue) {
#             document.cookie = 'KP_REF=; Path=/; Expires=Thu, 01 Jan 1970 00:00:00 GMT';
#         }
#     }
#     catch(e) {}
# </script><script src="//assets.adobedtm.com/6809d1ba6f0c/c4bef609fe0d/launch-b1aeef4798eb.min.js" data-testid="adobe-dtm-script" async=""></script><script src="https://www.realtor.com/assets/tracking-sdk/directSend.js" async=""></script><meta http-equiv="origin-trial" content=""><meta http-equiv="origin-trial" content=""><meta http-equiv="origin-trial" content=""><meta http-equiv="origin-trial" content=""><script src="https://securepubads.g.doubleclick.net/pagead/managed/js/gpt/m202502130101/pubads_impl.js" async=""></script><link href="https://securepubads.g.doubleclick.net/pagead/managed/dict/m202502180101/gpt" rel="compression-dictionary"><style data-styled="active" data-styled-version="5.1.0"></style><link rel="stylesheet" type="text/css" href="/assets/island-for-sale/prod/34a389b3/_next/static/css/035d8fcc23cb31f5.css"><link rel="stylesheet" type="text/css" href="/assets/island-for-sale/prod/34a389b3/_next/static/css/8721a8d3cd23259c.css"><link rel="stylesheet" type="text/css" href="/assets/island-for-sale/prod/34a389b3/_next/static/css/746cdf7103a4c05d.css"><link rel="stylesheet" type="text/css" href="/assets/island-for-sale/prod/34a389b3/_next/static/css/5bcf4587ef1f55f4.css"><link rel="stylesheet" type="text/css" href="/assets/island-for-sale/prod/34a389b3/_next/static/css/0d492da50c9aaef0.css"><meta name="apple-itunes-app" content="app-id=336698281"><script src="https://resources.digital-cloud-west.medallia.com/wdcwest/451725/onsite/embed.js" defer=""></script><script src="https://js.appboycdn.com/web-sdk/5.1/braze.min.js" async=""></script><script src="https://accounts.google.com/gsi/client" async="" defer=""></script><script src="/rdc_user_check/init.js" defer=""></script><link rel="stylesheet" type="text/css" href="/assets/island-for-sale/prod/34a389b3/_next/static/css/ef9424edc583d8c8.css"><link rel="stylesheet" type="text/css" href="/assets/island-for-sale/prod/34a389b3/_next/static/css/4ac116b4de8a73fd.css"><script src="https://assets.adobedtm.com/6809d1ba6f0c/c4bef609fe0d/b764a9fac5ab/RC0a3375e84d3e4eb685282e50186d1f9a-source.min.js" async=""></script><script src="https://assets.adobedtm.com/6809d1ba6f0c/c4bef609fe0d/b764a9fac5ab/RCb7464ec67e434ae7a31729f23ea157b2-source.min.js" async=""></script><script src="https://assets.adobedtm.com/6809d1ba6f0c/c4bef609fe0d/b764a9fac5ab/RCf6f4e9794d4b4fbcaabc20ca56040443-source.min.js" async=""></script><style id="ab-iam-css-definitions-5-1-1">.ab-pause-scrolling,body.ab-pause-scrolling,html.ab-pause-scrolling{overflow:hidden;touch-action:none}.ab-iam-root.v3{position:fixed;top:0;right:0;bottom:0;left:0;pointer-events:none;z-index:9011;-webkit-tap-highlight-color:transparent}.ab-iam-root.v3:focus{outline:0}.ab-iam-root.v3.ab-effect-fullscreen,.ab-iam-root.v3.ab-effect-html,.ab-iam-root.v3.ab-effect-modal{opacity:0}.ab-iam-root.v3.ab-effect-fullscreen.ab-show,.ab-iam-root.v3.ab-effect-html.ab-show,. ...
#             document.addEventListener('kpsdk-load', function () {
#                 window.KPSDK.configure([{"protocol":"https","method":"*","path":"/api/v1/user/share","domain":"www.realtor.com"},{"protocol":"https","method":"*","path":"/api/v1/rentals/user/share","domain":"www.realtor.com"},{"protocol":"https","method":"*","path":"/properties/share/email","domain":"www.realtor.com"},{"protocol":"https","method":"*","path":"/api/v1/leads/submitlead","domain":"www.realtor.com"},{"protocol":"https","method":"*","path":"/api/v1/rentals/leads/submitlead","domain":"www.realtor.com"},{"protocol":"https","method":"*","path":"/api/v1/submit_cross_sell","domain":"www.realtor.com"}])
#             });
#           </script><link rel="preload" href="/assets/island-for-sale/prod/34a389b3/_next/static/css/3b16cbd42398443c.css" as="style"><link rel="stylesheet" href="/assets/island-for-sale/prod/34a389b3/_next/static/css/3b16cbd42398443c.css" data-n-p=""><link rel="preload" href="/assets/island-for-sale/prod/34a389b3/_next/static/css/c69dd2a8f535ddf9.css" as="style"><link rel="stylesheet" href="/assets/island-for-sale/prod/34a389b3/_next/static/css/c69dd2a8f535ddf9.css"><link rel="preload" href="/assets/island-for-sale/prod/34a389b3/_next/static/css/a64076442b2366e9.css" as="style"><link rel="stylesheet" href="/assets/island-for-sale/prod/34a389b3/_next/static/css/a64076442b2366e9.css"><link rel="preload" href="/assets/island-for-sale/prod/34a389b3/_next/static/css/226fcfd818531375.css" as="style"><link rel="stylesheet" href="/assets/island-for-sale/prod/34a389b3/_next/static/css/226fcfd818531375.css"><link rel="preload" href="/assets/island-for-sale/prod/34a389b3/_next/static/css/0ae61fab34229973.css" as="style"><link rel="stylesheet" href="/assets/island-for-sale/prod/34a389b3/_next/static/css/0ae61fab34229973.css"><link rel="preload" href="/assets/island-for-sale/prod/34a389b3/_next/static/css/3d2b8239f38a708a.css" as="style"><link rel="stylesheet" href="/assets/island-for-sale/prod/34a389b3/_next/static/css/3d2b8239f38a708a.css"><link rel="preload" href="/assets/island-for-sale/prod/34a389b3/_next/static/css/96254203e6d925a8.css" as="style"><link rel="stylesheet" href="/assets/island-for-sale/prod/34a389b3/_next/static/css/96254203e6d925a8.css"><link rel="preload" href="/assets/island-for-sale/prod/34a389b3/_next/static/css/038f9762265144da.css" as="style"><link rel="stylesheet" href="/assets/island-for-sale/prod/34a389b3/_next/static/css/038f9762265144da.css"><link rel="preload" href="/assets/island-for-sale/prod/34a389b3/_next/static/css/cbb258d1c989afe0.css" as="style"><link rel="stylesheet" href="/assets/island-for-sale/prod/34a389b3/_next/static/css/cbb258d1c989afe0.css"><link rel="preload" href="/assets/island-for-sale/prod/34a389b3/_next/static/css/4949e83761dcf414.css" as="style"><link rel="stylesheet" href="/assets/island-for-sale/prod/34a389b3/_next/static/css/4949e83761dcf414.css"><noscript data-n-css=""></noscript><link rel="preload" href="/assets/island-for-sale/prod/34a389b3/_next/static/chunks/srp.ZeroOrEndOfResults.37292e83f9323a15.js" as="script"><link rel="preload" href="/assets/island-for-sale/prod/34a389b3/_next/static/chunks/srp.ExpandedSearchFilterModification.b0653feb2919fdf0.js" as="script"><link rel="preload" href="/assets/island-for-sale/prod/34a389b3/_next/static/chunks/srp.ExpandedSearchNearbyAreas.51508801ed887063.js" as="script"><link rel="preload" href="/assets/island-for-sale/prod/34a389b3/_next/static/chunks/57031.236340039a94c95b.js" as="script"><link rel="preload" href="/assets/island-for-sale/prod/34a389b3/_next/static/chunks/srp.NewHomesBuilderCarouselSection.6f9a8188ad3360a5.js" as="script"><link rel="preload" href="/assets/island-for-sale/prod/34a389b3/_next/static/chunks/srp.WidgetSection.b7786f95e5c39776.js" as="script"><link rel="preload" href="/assets/island-for-sale/prod/34a389b3/_next/static/chunks/srp.CrossLinkWidget.bc793ddbd2de5828.js" as="script"><link rel="preload" href="/assets/island-for-sale/prod/34a389b3/_next/static/chunks/srp.IdealLinkingModuleWidget.f4ec22447808001d.js" as="script"><link rel="preload" href="/assets/island-for-sale/prod/34a389b3/_next/static/chunks/srp.HomeValuesWidget.ef7d03628084842d.js" as="script"><link rel="preload" href="/assets/island-for-sale/prod/34a389b3/_next/static/chunks/srp.MarketTrendsWidget.af8fb76fc0a9e47a.js" as="script"><link rel="preload" href="/assets/island-for-sale/prod/34a389b3/_next/static/chunks/srp.SchoolsWidget.4692425a05b53bbe.js" as="script"><link rel="preload" href="/assets/island-for-sale/prod/34a389b3/_next/static/chunks/srp.HowToBuyHomeWidget.122067cbd7c77dc3.js" as="script"><link rel="preload" href="/assets/island-for-sa ...
#           window.__OPTIMIZELY_CACHE_ENTRIES__={"EXP_GLOBAL_HOLDOUT-undefined-{}":{"isEnabled":false,"variables":{"trackId":"GHFY25Q1"}},"WRS252_RAT_SAT_TEST-WRS252_RAT_SAT_TEST-{}":{"isEnabled":false,"variables":null,"variation":null},"WRS252_BOOST_TIER3-WRS252_BOOST_TIER3-{}":{"isEnabled":false,"variables":null,"variation":null},"wrl2411_mason_lead-wrl2411_mason_lead-{}":{"isEnabled":false,"variables":null,"variation":null},"WBS2411_AISEARCH_TEST3-WBS2411_AISEARCH_TEST3-{}":{"isEnabled":true,"variables":{},"variation":null},"WBS2410_AISEARCH_TEST2-WBS2410_AISEARCH_TEST2-{}":{"isEnabled":false,"variables":{},"variation":null},"WRS2410_RDC_LEAD_FORM-WRS2410_RDC_LEAD_FORM-{}":{"isEnabled":false,"variables":{},"variation":null},"WRS248_AD_CAROUSEL-WRS248_AD_CAROUSEL-{}":{"isEnabled":true,"variables":{},"variation":"V1"},"FS_SRP_RENTAL_CROSSLINK-FS_SRP_RENTAL_CROSSLINK-{}":{"isEnabled":true,"variables":{},"variation":"V1"},"RN_SRP_BYPASS_RAT_SAT-RN_SRP_BYPASS_RAT_SAT-{}":{"isEnabled":true,"variables":{},"variation":"V1"},"WRS248_PROMOTED_LIST-WRS248_PROMOTED_LIST-{}":{"isEnabled":true,"variables":{},"variation":"V1"},"RN_SRP_RENTAL_APPLICATIONS-RN_SRP_RENTAL_APPLICATIONS_202407-{}":{"isEnabled":true,"variables":{},"variation":"V1"},"WBS248_AISEARCH_TEST1-WBS248_AISEARCH_TEST1_23_09_2024-{}":{"isEnabled":false,"variables":{"Variation":"C"},"variation":null},"CCX_HP_SAVESEARCH_CONV_FEATURE-CCX_HP_SAVESEARCH_CONV_TEST_202306-{}":{"isEnabled":false,"variables":{},"variation":null},"RN_SRP_SHARE_RESULTS-RN_SRP_SHARE_RESULTS_202302-{}":{"isEnabled":false,"variables":{"Variation":"C"},"variation":null},"RN_SRP_FOCUSED_SEARCH-RN_SRP_FOCUSED_SEARCH_042024-{}":{"isEnabled":false,"variables":{"Variation":"V1"},"variation":null},"WBA2410_JEPSEN_YMAL-WBA2410_JEPSEN_YMAL-{}":{"isEnabled":false,"variables":{"Variation":"C"},"variation":null},"FOR_SALE_SRP_GLOBAL_HOLDOUT_1-FOR_SALE_SRP_GLOBAL_HOLDOUT_AA_TEST_1_202310-{}":{"isEnabled":false,"variables":{"Variation":""},"variation":null},"FOR_SALE_SRP_GLOBAL_HOLDOUT_2-FOR_SALE_SRP_GLOBAL_HOLDOUT_AA_TEST_2_202310-{}":{"isEnabled":false,"variables":{"Variation":""},"variation":null},"FOR_RENT_SRP_GLOBAL_HOLDOUT_AA_TEST_1_202310-FOR_RENT_SRP_GLOBAL_HOLDOUT_AA_TEST_1_202310-{}":{"isEnabled":false,"variables":{"Variation":"V1"},"variation":null},"FOR_RENT_SRP_GLOBAL_HOLDOUT_AA_TEST_2_202310-FOR_RENT_SRP_GLOBAL_HOLDOUT_AA_TEST_2_202310-{}":{"isEnabled":false,"variables":{"Variation":"V1"},"variation":null},"RS_SRP_INVITE_SHARED_LISTING-RS_SRP_INVITE_SHARED_LISTING_231213-{}":{"isEnabled":false,"variables":{"Variation":"C"},"variation":null},"WBA2412_MEDIA_PROGRAMMATIC_LIB-WBA2412_MEDIA_PROGRAMMATIC_LIB-{}":{"isEnabled":true,"variables":{"Variation":"V1"},"variation":"V1"},"Braze_First_Touch_Redirect_App_Download_Nudge_AB_Test_202311-Braze_First_Touch_Redirect_App_Download_Nudge_AB_Test_202311-{}":{"isEnabled":false,"variables":{"Variation":""},"variation":null},"SRP_RERANK_EXPERIMENT-undefined-{}":{"isEnabled":false,"variables":{"EXPERIMENT_KEY":"WBS252_FS_ALGO_ALT_FT","FEATURE_KEY":"WBS252_FS_ALGO_ALT"}},"WBS252_FS_ALGO_ALT-WBS252_FS_ALGO_ALT_FT-{}":{"isEnabled":false,"variables":{"Bucket_Values":{"sort":"fractal_v1.1.0"}},"variation":null},"WBS252_FS_ALGO_ALT-Bucket_Values-json-{}":{"sort":"fractal_v1.1.0"},"WBO241_PERSISTLEADDATA-WBO241_PERSISTLEADDATA-{}":{"isEnabled":true,"variables":{"Variation":"V1"},"variation":"V1"},"WNS2411_MAPPINV2-WNS2411_MAPPINV2-{}":{"isEnabled":false,"variables":{"Variation":""},"variation":null},"WBO2411_FORECAST_25-WBO2411_FORECAST_25-{}":{"isEnabled":true,"variables":{"Variation":""},"variation":"V1"},"RN_PINNED_LDP-{}":true,"GOOGLE_ONE_TAP_DELAY-delay-integer-{}":10000,"SRP_INTERACTION_DELAY-{}":false,"SRP_INTERACTION_DELAY-delay-integer-{}":5000,"WAA2410_AUTH0-WAA2410_AUTH0-{}":{"isEnabled":true,"variables":{"Variation":"V1"},"variation":"V1"},"WBS245_PROMOTEDLISTING-WBS245_PROMOTEDLISTING-{}":{"isEnabled":true,"variables":{"Variation":"C2"},"variation":"C2"},"WBS2411 ...
#           window.__OPTIMIZELY_INITIAL_PROPS__={"isDisabled":false,"userId":"2b4c5bb7-9ab4-45ff-a347-51c0bcbe2838","attributes":{},"userAgent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36","usePrimedCacheWhenDisabled":true,"queryParams":{"slug":["13337"]},"project":"RDCX","env":"production","enableHoldouts":true,"amplitudeApiKey":"8d4736ddd8febfe6c8a83797a026a1b7","deploymentKey":"client-qnsvYjylo3T9uqP98Ez8ud3TAIWpY1hR"}
#           window.__AMPLITUDE_CACHE_ENTRIES__={}
#           window.__AMPLITUDE_INITIAL_PROPS__={"isDisabled":false,"userId":"2b4c5bb7-9ab4-45ff-a347-51c0bcbe2838","attributes":{},"userAgent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36","usePrimedCacheWhenDisabled":true,"queryParams":{"slug":["13337"]},"project":"RDCX","env":"production","enableHoldouts":true,"amplitudeApiKey":"8d4736ddd8febfe6c8a83797a026a1b7","deploymentKey":"client-qnsvYjylo3T9uqP98Ez8ud3TAIWpY1hR"}
#           </script><script src="https://launchpad-wrapper.privacymanager.io/995785b3-d817-4754-9676-01064fdf7627/launchpad-liveramp.js" type="text/javascript" async="" defer=""></script><iframe style="display:none;opacity:0;visibility:hidden;border:0;width:0;height:0;" name="__uspapiLocator"></iframe><iframe marginwidth="0" marginheight="0" scrolling="no" frameborder="0" id="13525886e8057a" width="0" height="0" src="about:blank" name="__pb_locator__" style="display: none; height: 0px; width: 0px; border: 0px;"></iframe><div class="ModalDialogstyles__StyledModalBase-rui__sc-1eb0o4f-0 KuMEW CaptchaModalstyles__StyledModal-rui__sc-1let1i-0 bfsjBW"></div><next-route-announcer><p aria-live="assertive" id="__next-route-announcer__" role="alert" style="border: 0px; clip: rect(0px, 0px, 0px, 0px); height: 1px; margin: -1px; overflow: hidden; padding: 0px; position: absolute; width: 1px; white-space: nowrap; overflow-wrap: normal;"></p></next-route-announcer><script>
# //facebook pixel
# !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
# n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
# document,'script','https://connect.facebook.net/en_US/fbevents.js');
#
# var isFbPixelAllowed = document.location.pathname.indexOf('/new') == -1 && document.location.pathname.indexOf('/advic') == -1 && document.location.pathname.indexOf('/videos') == -1;
# var isFacebookPixelAllowed = document.location.pathname.indexOf('/espano') == -1 && document.location.pathname.indexOf('/agentonboardin') == -1 && document.location.pathname.indexOf('/welcome') == -1;
# var isMetaPixelAllowed = document.location.pathname.indexOf('/naa2022') == -1 && document.location.pathname.indexOf('/sponsored') == -1 && document.location.pathname.indexOf('/creative-service') == -1 && document.location.pathname.indexOf('/foreveryone') == -1;
#
# var url = new URL(document.location);
# var urlParams = url.searchParams;
# var blockFacebookPixelForPrivacyViolations = urlParams.has("mortgageBalance") || urlParams.has("credit_score");
#
# if (typeof fbInitCheck === "undefined" && isFbPixelAllowed && isFacebookPixelAllowed && isMetaPixelAllowed && !blockFacebookPixelForPrivacyViolations) {
#   fbInitCheck = true;
#   fbq('init', '754678604575607', {'external_id': _satellite.cookie.get('__vst')});
#
#   if (_satellite.getVar("site") == "news_insights" && /^.+?_article$/.test(_satellite.getVar('pageType'))) {
#     fbq('trackSingleCustom', '754678604575607', 'EditorialView', {
#       pageType: _satellite.getVar('pageType'),
#       category: _satellite.getVar('Editorial Category'),
#       articleTag: _satellite.getVar('Editorial Tags')
#     });
#   }
# }
#
# </script><script>_satellite["_runScript1"](function(event, target, Promise) {
# !function(){var e={330:function(e,t,a){var n=a(320);e.exports=function(e,t,a){var i=a.vendors,r=!1,o={segmentWriteKey:a.qaSegmentWriteKey,adobeOrgID:a.adobeOrgID,sampling:{}};for(var s in i)o.sampling[s]=100;var c=[];function l(n){if(c)return c.push(n);var i=n.type,r=n.properties,o=n.pageName,s=n.eventName,l=n.filters,d=n.callback,u=t.getVisitorID(),g=Object.assign({},r,{adobeMcid:u}),p=null!=a&&"none"!==a.assignSiteCatalystVisitorIDTo?g[a.assignSiteCatalystVisitorIDTo]:"",m=Object.assign({},g,{adobeVisitorId:p});return"page"===i?e.trackPage(o,m,l):"track"===i?d?e.trackEvent(s,m,l,d):e.trackEvent(s,m,l):void 0}return t.onReceiveEcid(o,(function(){var e=c;for(c=null;e.length>0;)l(e.shift())})),{init:function(t){var a=!1;for(var n in t)"segmentWriteKey"==n&&(a=!0),o[n]=t[n];a&&e.initializeSegment(o.segmentWriteKey)},trackPage:function(e,s,c){r||(s=s||{},t.setCurrentPage(e,s),t.qualifiedAfterSampling(i.segment,o)&&(l({type:"page",pageName:e,properties:t.getGlobalVariables("pageView",s),filters:t.processFiltersOnIntegration(c,o)}),n.function(a.trackPageCallback)&&a.trackPageCallback(e,s)))},trackEvent:function(e,s,c,d){if(!r&&(s=s||{},t.qualifiedAfterSampling(i.segment,o))){void 0===d&&(d=!1),"click"==e&&void 0!==a.forceStoreAndForwardOnClick&&a.forceStoreAndForwardOnClick&&(d=a.forceStoreAndForwardOnClick);var u=t.getGlobalVariables(e,s),g=t.processFiltersOnIntegration(c,o),p={type:"track",eventName:e,properties:u,filters:g};if("function"!=typeof a.shouldBlockEvent||!a.shouldBlockEvent(u)){if(d&&t.checkLocalStorageAvailability()){var m={evt:e,props:u,integrations:g,ts:(new Date).getTime()},v=t.getRandomGUID();t.addBeaconToLocalStorage(v,m),Object.assign(p,{callback:function(){t.removeBeaconFromLocalStorage(v)}}),l(p)}else l(p);n.function(a.trackEventCallback)&&a.trackEventCallback(u)}}},identify:function(a,n,i,s){r||e.identify(a,n,t.processFiltersOnIntegration(i,o),s)},debug:function(a){e.debug(a),t.setDebugState(a)},log:function(e){t.log(e)},integrations:i,getMoveConfig:function(){return o},getPreventSegmentCalls:function(){return r},setPreventSegmentCalls:function(e){r=e},version:"b2c-0.183.0-prod"}}},925:function(e,t,a){function n(e,t){var a=Object.keys(e);if(Object.getOwnPropertySymbols){var n=Object.getOwnPropertySymbols(e);t&&(n=n.filter((function(t){return Object.getOwnPropertyDescriptor(e,t).enumerable}))),a.push.apply(a,n)}return a}function i(e){for(var t=1;t<arguments.length;t++){var a=null!=arguments[t]?arguments[t]:{};t%2?n(Object(a),!0).forEach((function(t){r(e,t,a[t])})):Object.getOwnPropertyDescriptors?Object.defineProperties(e,Object.getOwnPropertyDescriptors(a)):n(Object(a)).forEach((function(t){Object.defineProperty(e,t,Object.getOwnPropertyDescriptor(a,t))}))}return e}function r(e,t,a){return t in e?Object.defineProperty(e,t,{value:a,enumerable:!0,configurable:!0,writable:!0}):e[t]=a,e}function o(e){return o="function"==typeof Symbol&&"symbol"==typeof Symbol.iterator?function(e){return typeof e}:function(e){return e&&"function"==typeof Symbol&&e.constructor===Symbol&&e!==Symbol.prototype?"symbol":typeof e},o(e)}var s=a(320);e.exports=function(e,t,a){var n=this,r=!1;function c(e){var t=("; "+document.cookie).split("; "+e+"=");return 2===t.length?t.pop().split(";").shift():null}function l(){if(!r&&void 0===window.COMSCORE){var e=document.createElement("script"),t=document.getElementsByTagName("script")[0];e.async=!0,e.src=("https:"==document.location.protocol?"https://sb":"http://b")+".scorecardresearch.com/cs/6036093/beacon.js",t.parentNode.insertBefore(e,t),r=!0}}function d(e,a,n){if(window.ignoreNextComscorePixelForPage!==window.location.origin+window.location.pathname){window.ignoreNextComscorePixelForPage=null,"object"===o(e)&&(e="true"===c("ccpaoptout")?Object.assign({},e,{cs_fpid:"*null",cs_fpit:"*null",cs_ucfr:"*null",cs_fpdm:"*null",cs_fpdt:"*null"}):Object.assign({},e,{cs_fpid:a,cs_fpit:"c",cs_ucfr:n,cs_fpdm:"*null",cs_fpdt:"*null"}));try{if(void 0!==window.COMSCORE&&"function"==typeof window.COMSCORE.b ...
# });</script><script async="" type="text/javascript" src="//us.tags.newscgp.com/prod/ncg/ncg.js"></script><script async="" type="text/javascript" src="https://secure.quantserve.com/quant.js"></script><script>
# var script = document.createElement('script'),
# 	scripts = document.getElementsByTagName('script')[0];
# script.src = "//pixel.everesttech.net/rlsa/5154";
# script.async = !0;
# scripts.parentNode.insertBefore(script, scripts);
# </script><iframe name="__launchpadLocator" style="display: none;"></iframe><div class="ModalDialogstyles__StyledModalBase-rui__sc-1eb0o4f-0 lRCly MovingCostCalculatorModalstyles__StyledMovingCostCalculatorModal-rui__sc-18oxahq-0 jAXVeC"></div><iframe sandbox="allow-scripts allow-same-origin" title="Adobe ID Syncing iFrame" id="destination_publishing_iframe_moveinc_0" name="destination_publishing_iframe_moveinc_0_name" src="https://moveinc.demdex.net/dest5.html?d_nsid=0#https%3A%2F%2Fwww.realtor.com" class="aamIframeLoaded" style="display: none; width: 0px; height: 0px;"></iframe><img src="https://pt.ispot.tv/v2/TC-3511-1.gif?app=web&amp;type=visit&amp;customdata=for_sale,srp_list" style="display: none;"><img src="https://pt.ispot.tv/v2/TC-3060-7.gif?app=web&amp;type=visit&amp;customdata=for_sale,srp_list" style="display: none;"><script>_satellite["_runScript2"](function(event, target, Promise) {
# "undefined"!=typeof fbq&&fbq("trackSingleCustom","754678604575607","AddToWishlist"),gtag("event","conversion",{send_to:"DC-10291144/convert/visit+per_session"}),gtag("event","conversion",{send_to:"DC-10291144/convert/visitor+unique"});
# });</script><script>
# !function(){var t=function(t,e,n,i){this.get=function(t){t+="=";for(var e=document.cookie.split(";"),n=0,i=e.length;n<i;n++){for(var r=e[n];" "==r.charAt(0);)r=r.substring(1,r.length);if(0==r.indexOf(t))return r.substring(t.length,r.length)}return null},this.set=function(t,e){var n="";(n=new Date).setTime(n.getTime()+6048e5),n="; expires="+n.toGMTString(),document.cookie=t+"="+e+n+"; path=/; "},this.check=function(){var i=this.get(n);if(i)i=i.split(":");else{if(100==t)return!0;"v"==e&&(t=Math.random()>=t/100?0:100),i=[e,t,0],this.set(n,i.join(":"))}var r=i[1];if(100==r)return!0;switch(i[0]){case"v":return!1;case"r":return r=i[2]%Math.floor(100/r),i[2]++,this.set(n,i.join(":")),!r}return!0},this.go=function(){if(this.check()){var t=document.createElement("script");t.defer=!0,t.async=!0,t.type="text/javascript",t.src=i+"&t="+(new Date).getTime(),document.body&&document.body.appendChild(t)}},this.start=function(){var t=this;"complete"==document.readyState?t.go():window.addEventListener?window.addEventListener("load",(function(){t.go()}),!1):window.attachEvent&&window.attachEvent("onload",(function(){t.go()}))}};try{new t(100,"r","QSI_S_ZN_8p1dPH4RgQzWV0x","https://zn8p1dph4rgqzwv0x-move.siteintercept.qualtrics.com/WRSiteInterceptEngine/?Q_ZID=ZN_8p1dPH4RgQzWV0x&Q_LOC="+encodeURIComponent(window.location.href)).start()}catch(t){}}();var qualtricsDiv=document.createElement("div");qualtricsDiv.setAttribute("id","ZN_8p1dPH4RgQzWV0x"),document.body.appendChild(qualtricsDiv);
# </script><div id="ZN_8p1dPH4RgQzWV0x"></div><script>
# var s=document.createElement("script");s.setAttribute("src","//www.everestjs.net/static/le/last-event-tag-latest.min.js"),s.onload=function(){AdCloudEvent("AMCV_8853394255142B6A0A4C98A4@AdobeOrg","homerealtor")},document.body.appendChild(s);
# </script><script src="//www.everestjs.net/static/le/last-event-tag-latest.min.js"></script><iframe width="0" height="0" frameborder="0" aria-hidden="true" title="News ID" id="ncg_cookie_60288-1739916327465" src="//www.ncaudienceexchange.com/prod/ncg/cookie.html"></iframe><iframe width="0" height="0" frameborder="0" aria-hidden="true" title="News ID" id="ncg_cookie_38912-1739916327469" src="//tags.barrons.com/prod/ncg/cookie.html"></iframe><iframe width="0" height="0" frameborder="0" aria-hidden="true" title="News ID" id="ncg_cookie_98430-1739916327470" src="//tags.mansionglobal.com/prod/ncg/cookie.html"></iframe><iframe width="0" height="0" frameborder="0" aria-hidden="true" title="News ID" id="ncg_cookie_12168-1739916327471" src="//tags.marketwatch.com/prod/ncg/cookie.html"></iframe><iframe width="0" height="0" frameborder="0" aria-hidden="true" title="News ID" id="ncg_cookie_41212-1739916327472" src="//tags.wsj.com/prod/ncg/cookie.html"></iframe><iframe width="0" height="0" frameborder="0" aria-hidden="true" title="News ID" id="ncg_cookie_79020-1739916327473" src="//tags.nypost.com/prod/ncg/cookie.html"></iframe><iframe width="0" height="0" frameborder="0" aria-hidden="true" title="News ID" id="ncg_cookie_65182-1739916327474" src="//tags.decider.com/prod/ncg/cookie.html"></iframe><iframe width="0" height="0" frameborder="0" aria-hidden="true" title="News ID" id="ncg_cookie_55648-1739916327474" src="//tags.pagesix.com/prod/ncg/cookie.html"></iframe><iframe width="0" height="0" frameborder="0" aria-hidden="true" title="News ID" id="ncg_cookie_29127-1739916327475" src="//tags.penews.com/prod/ncg/cookie.html"></iframe><script id="" text="" charset="" type="text/javascript" src="https://ob.isstarsbuilding.com/i/40afa80528860afbe67fc3cf23865892.js"></script><iframe height="0" width="0" style="display: none; visibility: hidden;"></iframe><iframe height="0" width="0" src="https://10291144.fls.doubleclick.net/activityi;src=10291144;type=retarget;cat=wholesit;ord=6530988941672;npa=0;auiddc=539477173.1739916328;ps=1;pcor=1088499699;uaa=;uab=;uafvl=;uamb=0;uam=;uap=Windows;uapv=;uaw=0;pscdl=noapi;frm=0;gtm=45fe52d0v9183562736za200;gcd=13l3l3l3l1l1;dma=0;tag_exp=101509157~102067808~102482433~102539968~102558064~102587591~102605417~102640599;epver=2;~oref=https%3A%2F%2Fwww.realtor.com%2Frealestateandhomes-search%2F13337?" style="display: none; visibility: hidden;"></iframe><iframe allow="join-ad-interest-group" data-tagging-id="DC-10291144/retarget/wholesit+standard" data-load-time="1739916327864" height="0" width="0" src="https://td.doubleclick.net/td/fls/rul/activityi;fledge=1;src=10291144;type=retarget;cat=wholesit;ord=6530988941672;npa=0;auiddc=539477173.1739916328;ps=1;pcor=1088499699;uaa=;uab=;uafvl=;uamb=0;uam=;uap=Windows;uapv=;uaw=0;pscdl=noapi;frm=0;gtm=45fe52d0v9183562736za200;gcd=13l3l3l3l1l1;dma=0;tag_exp=101509157~102067808~102482433~102539968~102558064~102587591~102605417~102640599;epver=2;~oref=https%3A%2F%2Fwww.realtor.com%2Frealestateandhomes-search%2F13337?" style="display: none; visibility: hidden;"></iframe><iframe height="0" width="0" src="https://10291144.fls.doubleclick.net/activityi;src=10291144;type=leads;cat=pageview;ord=1101194454871;npa=0;auiddc=539477173.1739916328;ps=1;pcor=860748030;uaa=;uab=;uafvl=;uamb=0;uam=;uap=Windows;uapv=;uaw=0;pscdl=noapi;frm=0;gtm=45fe52d0v9183562736za200;gcd=13l3l3l3l1l1;dma=0;tag_exp=101509157~102067808~102482433~102539968~102558064~102587591~102605417~102640599;epver=2;~oref=https%3A%2F%2Fwww.realtor.com%2Frealestateandhomes-search%2F13337?" style="display: none; visibility: hidden;"></iframe><iframe allow="join-ad-interest-group" data-tagging-id="DC-10291144/leads/pageview+standard" data-load-time="1739916327869" height="0" width="0" src="https://td.doubleclick.net/td/fls/rul/activityi;fledge=1;src=10291144;type=leads;cat=pageview;ord=1101194454871;npa=0;auiddc=539477173.1739916328;ps=1;pcor=860748030;uaa=;uab=;uafvl=;uamb=0;uam=;uap=Windows;uapv=;uaw=0;pscdl=noapi;frm=0;gtm=45 ...
#     </iframe><iframe sandbox="allow-scripts allow-same-origin" id="284c3984ab493e5" frameborder="0" allowtransparency="true" marginheight="0" marginwidth="0" width="0" hspace="0" vspace="0" height="0" style="height:0px;width:0px;display:none;" scrolling="no" src="https://ssum-sec.casalemedia.com/usermatch?s=184674&amp;gdpr=&amp;gdpr_consent=&amp;us_privacy=&amp;gpp=&amp;gppsid=&amp;cb=https%3A%2F%2Fow.pubmatic.com%2Fsetuid%3Fbidder%3Dix%26gdpr%3D%26gdpr_consent%3D%26gpp%3D%26gpp_sid%3D%26f%3Db%26uid%3D">
#     </iframe><iframe sandbox="allow-scripts allow-same-origin" id="29cd7275aa7ed9c" frameborder="0" allowtransparency="true" marginheight="0" marginwidth="0" width="0" hspace="0" vspace="0" height="0" style="height:0px;width:0px;display:none;" scrolling="no" src="https://ads.pubmatic.com/AdServer/js/user_sync.html?gdpr=&amp;gdpr_consent=&amp;us_privacy=&amp;predirect=https%3A%2F%2Fow.pubmatic.com%2Fsetuid%3Fbidder%3Dpubmatic%26gdpr%3D%26gdpr_consent%3D%26gpp%3D%26gpp_sid%3D%26f%3Db%26uid%3D">
#     </iframe><iframe sandbox="allow-scripts allow-same-origin" id="300010e902b6b12" frameborder="0" allowtransparency="true" marginheight="0" marginwidth="0" width="0" hspace="0" vspace="0" height="0" style="height:0px;width:0px;display:none;" scrolling="no" src="https://eb2.3lift.com/sync?gdpr=&amp;cmp_cs=&amp;us_privacy=&amp;gpp=&amp;gpp_sid=&amp;redir=https%3A%2F%2Fow.pubmatic.com%2Fsetuid%3Fbidder%3Dtriplelift%26gdpr%3D%26gdpr_consent%3D%26gpp%3D%26gpp_sid%3D%26f%3Db%26uid%3D%24UID">
#     </iframe><iframe sandbox="allow-scripts allow-same-origin" id="536af7b1da4844e" frameborder="0" allowtransparency="true" marginheight="0" marginwidth="0" width="0" hspace="0" vspace="0" height="0" style="height:0px;width:0px;display:none;" scrolling="no" src="https://eb2.3lift.com/sync?us_privacy=1---&amp;">
#     </iframe><iframe sandbox="allow-scripts allow-same-origin" id="542ac45536f1c9b" frameborder="0" allowtransparency="true" marginheight="0" marginwidth="0" width="0" hspace="0" vspace="0" height="0" style="height:0px;width:0px;display:none;" scrolling="no" src="https://gum.criteo.com/syncframe?origin=criteoPrebidAdapter&amp;topUrl=www.realtor.com&amp;us_privacy=1---&amp;gpp=#{%22cw%22:true,%22lsw%22:true,%22origin%22:%22criteoPrebidAdapter%22,%22requestId%22:%220.9870939623318922%22,%22tld%22:%22www.realtor.com%22,%22topUrl%22:%22www.realtor.com%22,%22version%22:%229_30_0%22}">
#     </iframe><iframe sandbox="allow-scripts allow-same-origin" id="55c44f3708f9e7e" frameborder="0" allowtransparency="true" marginheight="0" marginwidth="0" width="0" hspace="0" vspace="0" height="0" style="height:0px;width:0px;display:none;" scrolling="no" src="https://eus.rubiconproject.com/usync.html?us_privacy=1---">
#     </iframe><iframe sandbox="allow-scripts allow-same-origin" id="56fd9236263246d" frameborder="0" allowtransparency="true" marginheight="0" marginwidth="0" width="0" hspace="0" vspace="0" height="0" style="height:0px;width:0px;display:none;" scrolling="no" src="https://acdn.adnxs.com/dmp/async_usersync.html">
#     </iframe><iframe sandbox="allow-scripts allow-same-origin" id="570dccb46823532" frameborder="0" allowtransparency="true" marginheight="0" marginwidth="0" width="0" hspace="0" vspace="0" height="0" style="height:0px;width:0px;display:none;" scrolling="no" src="https://ads.pubmatic.com/AdServer/js/user_sync.html?kdntuid=1&amp;p=161223&amp;us_privacy=1---">
#     </iframe></html>

# %%
driver.quit()
